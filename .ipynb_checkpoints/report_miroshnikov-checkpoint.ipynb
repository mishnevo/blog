# %% [markdown]
# <div style='text-align:center;font-family:serif;padding:60px 20px'>
#
# # Министерство науки и высшего образования Российской Федерации
#
# ---
#
# ## Лабораторная работа
#
# # «Разработка веб-приложения блога на Flask с REST API»
#
# ---
#
# | | |
# |---|---|
# | **Дисциплина** | Веб-разработка на Python |
# | **Вариант** | 5 — REST API |
# | **Студент** | Мирошников Михаил Константинович |
# | **Группа** | М092501(70) |
# | **Дата** | 08.05.2025 |
#
# </div>

# %% [markdown]
# # 2. Описание проекта
#
# ## 2.1 Выбранный вариант
#
# **Вариант 5 — REST API.** Выбран, поскольку REST API является стандартом современной веб-разработки и позволяет отделить серверную логику от клиентской части. Реализация полного CRUD-интерфейса через HTTP-методы (GET, POST, PUT, DELETE) даёт практический опыт построения программных интерфейсов, востребованных в реальных проектах.
#
# ## 2.2 Реализованный функционал
#
# ### Обязательный минимум (Вариант 5)
#
# | Эндпоинт | Метод | Описание |
# |---|---|---|
# | `/api/posts` | GET | Список всех постов с пагинацией и фильтрацией |
# | `/api/posts/<id>` | GET | Конкретный пост по ID |
# | `/api/posts` | POST | Создание нового поста |
# | `/api/posts/<id>` | PUT | Обновление поста |
# | `/api/posts/<id>` | DELETE | Удаление поста |
# | `/api/docs` | GET | Документация API |
#
# - **Аутентификация** через API-ключ (заголовок `X-API-Key` или параметр `?api_key=`)
# - **Обработка ошибок** с правильными HTTP-кодами: 400, 401, 404, 422, 500
# - **Фильтрация и сортировка** (доп. баллы): параметры `?q=`, `?sort=asc/desc`
#
# ### Индивидуальные особенности
#
# **1. Пагинация** — главная страница и API поддерживают разбивку на страницы по 5 постов. Параметр `?page=N` работает как в веб-интерфейсе, так и в API.
#
# **2. Экспорт в CSV** — маршрут `/export/csv` формирует файл `posts_export.csv` со всеми постами и отдаёт его браузеру для скачивания.
#
# ## 2.3 Скриншоты приложения
#
# > Скриншоты сделаны при локальном запуске `flask run` по адресу `http://127.0.0.1:5000`
#
# ### Главная страница
# ```
# [Скриншот главной страницы — список постов с пагинацией и строкой поиска]
# ```
#
# ### Страница отдельного поста
# ```
# [Скриншот страницы поста — заголовок, дата, содержание, кнопки Edit / Back]
# ```
#
# ### Форма создания поста
# ```
# [Скриншот формы Create a New Post — поля Title и Content, кнопка Submit]
# ```

# %% [markdown]
# # 3. Структура базы данных
#
# ## 3.1 SQL-схема

# %%
schema_sql = """
DROP TABLE IF EXISTS posts;

CREATE TABLE posts (
    id      INTEGER PRIMARY KEY AUTOINCREMENT,
    created TIMESTAMP NOT NULL DEFAULT CURRENT_TIMESTAMP,
    title   TEXT NOT NULL,
    content TEXT NOT NULL
);
"""
print(schema_sql)

# %% [markdown]
# ## 3.2 Описание полей таблицы `posts`
#
# | Поле | Тип | Ограничение | Описание |
# |---|---|---|---|
# | `id` | INTEGER | PRIMARY KEY, AUTOINCREMENT | Уникальный идентификатор, увеличивается автоматически |
# | `created` | TIMESTAMP | NOT NULL, DEFAULT CURRENT_TIMESTAMP | Дата и время создания, устанавливается автоматически |
# | `title` | TEXT | NOT NULL | Заголовок поста, обязательное поле |
# | `content` | TEXT | NOT NULL | Текстовое содержание, обязательное поле |
#
# ## 3.3 Диаграмма
#
# ```
# ┌─────────────────────────┐
# │          posts           │
# ├──────────┬──────────────┤
# │ id       │ INTEGER  PK  │
# │ created  │ TIMESTAMP    │
# │ title    │ TEXT         │
# │ content  │ TEXT         │
# └──────────┴──────────────┘
# ```
#
# Одна таблица `posts`, внешних ключей нет — минималистичная архитектура блога без системы пользователей.

# %% [markdown]
# # 4. Ключевые фрагменты кода
#
# ## 4.1 Декоратор аутентификации по API-ключу

# %%
from functools import wraps
from flask import request, jsonify

API_KEY = 'demo-api-key-12345'

def require_api_key(f):
    """
    Декоратор: проверяет наличие корректного API-ключа
    в заголовке X-API-Key или параметре запроса ?api_key=.
    Возвращает 401 Unauthorized при неверном ключе.
    """
    @wraps(f)
    def decorated(*args, **kwargs):
        key = request.headers.get('X-API-Key') or request.args.get('api_key')
        if key != API_KEY:
            return jsonify({'error': 'Unauthorized. Provide a valid API key.'}), 401
        return f(*args, **kwargs)
    return decorated

# %% [markdown]
# Декоратор применяется ко всем пяти API-маршрутам через `@require_api_key`. Ключ принимается двумя способами: через HTTP-заголовок (рекомендуется) или через GET-параметр (удобно для тестирования в браузере).
#
# ---
#
# ## 4.2 GET /api/posts — список постов

# %%
@app.route('/api/posts', methods=['GET'])
@require_api_key
def api_get_posts():
    """
    GET /api/posts — список постов с пагинацией, поиском и сортировкой.
    Параметры: page, per_page (макс. 50), sort (asc/desc), q (поиск)
    """
    page     = max(1, request.args.get('page', 1, type=int))
    per_page = min(50, max(1, request.args.get('per_page', 5, type=int)))
    sort     = request.args.get('sort', 'desc').lower()
    q        = request.args.get('q', '').strip()

    if sort not in ('asc', 'desc'):
        sort = 'desc'   # защита от некорректного значения

    order  = f'created {sort.upper()}'
    offset = (page - 1) * per_page
    conn   = get_db_connection()

    if q:
        total = conn.execute(
            'SELECT COUNT(*) FROM posts WHERE title LIKE ? OR content LIKE ?',
            (f'%{q}%', f'%{q}%')
        ).fetchone()[0]
        rows = conn.execute(
            f'SELECT * FROM posts WHERE title LIKE ? OR content LIKE ?'
            f' ORDER BY {order} LIMIT ? OFFSET ?',
            (f'%{q}%', f'%{q}%', per_page, offset)
        ).fetchall()
    else:
        total = conn.execute('SELECT COUNT(*) FROM posts').fetchone()[0]
        rows  = conn.execute(
            f'SELECT * FROM posts ORDER BY {order} LIMIT ? OFFSET ?',
            (per_page, offset)
        ).fetchall()

    conn.close()
    total_pages = (total + per_page - 1) // per_page

    return jsonify({
        'posts': [dict(r) for r in rows],
        'pagination': {
            'page': page, 'per_page': per_page,
            'total': total, 'total_pages': total_pages,
            'has_next': page < total_pages,
            'has_prev': page > 1,
        }
    }), 200

# %% [markdown]
# ---
#
# ## 4.3 GET /api/posts/\<id\> — конкретный пост

# %%
@app.route('/api/posts/<int:post_id>', methods=['GET'])
@require_api_key
def api_get_post(post_id):
    """GET /api/posts/<id> — возвращает один пост по ID."""
    conn = get_db_connection()
    row  = conn.execute('SELECT * FROM posts WHERE id = ?', (post_id,)).fetchone()
    conn.close()

    if row is None:
        return jsonify({'error': f'Post {post_id} not found.'}), 404

    return jsonify(dict(row)), 200

# %% [markdown]
# ---
#
# ## 4.4 POST /api/posts — создание поста с валидацией

# %%
@app.route('/api/posts', methods=['POST'])
@require_api_key
def api_create_post():
    """
    POST /api/posts — создание поста.
    Тело: JSON { "title": "...", "content": "..." }
    Возвращает созданный пост с кодом 201 Created.
    """
    data = request.get_json(silent=True)   # silent=True — не падает на невалидном JSON
    if not data:
        return jsonify({'error': 'Invalid or missing JSON body.'}), 400

    title   = data.get('title',   '').strip()
    content = data.get('content', '').strip()

    if not title:
        return jsonify({'error': 'Field "title" is required.'}), 422
    if not content:
        return jsonify({'error': 'Field "content" is required.'}), 422

    conn = get_db_connection()
    cur  = conn.execute(
        'INSERT INTO posts (title, content) VALUES (?, ?)', (title, content)
    )
    conn.commit()
    row = conn.execute('SELECT * FROM posts WHERE id = ?', (cur.lastrowid,)).fetchone()
    conn.close()

    return jsonify(dict(row)), 201

# %% [markdown]
# ---
#
# ## 4.5 PUT /api/posts/\<id\> — обновление поста

# %%
@app.route('/api/posts/<int:post_id>', methods=['PUT'])
@require_api_key
def api_update_post(post_id):
    """
    PUT /api/posts/<id> — обновление поста.
    Тело: JSON { "title": "...", "content": "..." }
    Можно передать только одно поле — второе сохранится без изменений.
    """
    conn = get_db_connection()
    row  = conn.execute('SELECT * FROM posts WHERE id = ?', (post_id,)).fetchone()
    if row is None:
        conn.close()
        return jsonify({'error': f'Post {post_id} not found.'}), 404

    data = request.get_json(silent=True)
    if not data:
        conn.close()
        return jsonify({'error': 'Invalid or missing JSON body.'}), 400

    # Если поле не передано — берём старое значение из БД (частичное обновление)
    title   = data.get('title',   row['title']).strip()
    content = data.get('content', row['content']).strip()

    if not title:
        conn.close()
        return jsonify({'error': 'Field "title" cannot be empty.'}), 422

    conn.execute(
        'UPDATE posts SET title = ?, content = ? WHERE id = ?',
        (title, content, post_id)
    )
    conn.commit()
    updated = conn.execute('SELECT * FROM posts WHERE id = ?', (post_id,)).fetchone()
    conn.close()

    return jsonify(dict(updated)), 200

# %% [markdown]
# ---
#
# ## 4.6 DELETE /api/posts/\<id\> — удаление поста

# %%
@app.route('/api/posts/<int:post_id>', methods=['DELETE'])
@require_api_key
def api_delete_post(post_id):
    """DELETE /api/posts/<id> — безвозвратно удаляет пост."""
    conn = get_db_connection()
    row  = conn.execute('SELECT * FROM posts WHERE id = ?', (post_id,)).fetchone()
    if row is None:
        conn.close()
        return jsonify({'error': f'Post {post_id} not found.'}), 404

    conn.execute('DELETE FROM posts WHERE id = ?', (post_id,))
    conn.commit()
    conn.close()

    return jsonify({'message': f'Post {post_id} deleted successfully.'}), 200

# %% [markdown]
# ---
#
# ## 4.7 GET /api/docs — страница документации

# %%
@app.route('/api/docs')
def api_docs():
    """
    GET /api/docs — публичная HTML-страница с документацией REST API.
    Аутентификация не требуется.
    Передаёт api_key в шаблон для отображения в примерах curl-команд.
    """
    return render_template('api_docs.html', api_key=API_KEY)

# %% [markdown]
# ---
#
# ## 4.8 Обработчики ошибок

# %%
@app.errorhandler(404)
def not_found(e):
    """Для API — JSON, для веб — HTML-шаблон."""
    if request.path.startswith('/api/'):
        return jsonify({'error': 'Not found.'}), 404
    return render_template('404.html'), 404

@app.errorhandler(405)
def method_not_allowed(e):
    if request.path.startswith('/api/'):
        return jsonify({'error': 'Method not allowed.'}), 405
    return render_template('404.html'), 405

@app.errorhandler(500)
def internal_error(e):
    if request.path.startswith('/api/'):
        return jsonify({'error': 'Internal server error.'}), 500
    return render_template('404.html'), 500

# %% [markdown]
# # 5. Инструкция по установке и запуску

# %%
# Шаг 1. Клонировать репозиторий
# git clone <ваш-репозиторий>
# cd blog

# Шаг 2. Создать виртуальное окружение
# python -m venv venv
# source venv/bin/activate        # Linux / Mac
# venv\Scripts\activate           # Windows

# Шаг 3. Установить зависимости
# pip install -r requirements.txt

# Шаг 4. Инициализировать БД (создаст database.db с тестовыми постами)
# python init_db.py

# Шаг 5. Запустить
# flask --app app run --debug

# Веб:  http://127.0.0.1:5000
# API:  http://127.0.0.1:5000/api/posts
# Docs: http://127.0.0.1:5000/api/docs

print('Инструкция по запуску — см. комментарии выше')

# %% [markdown]
# ## 5.2 requirements.txt
#
# ```
# Flask>=2.3,<3.0
# Werkzeug>=2.3,<3.0
# ```
#
# ## 5.3 Структура проекта
#
# ```
# blog/
# ├── app.py                  ← основное приложение Flask
# ├── init_db.py              ← инициализация БД
# ├── schema.sql              ← SQL-схема
# ├── requirements.txt
# ├── README.md
# ├── .gitignore
# ├── database.db             ← создаётся после python init_db.py
# ├── templates/
# │   ├── base.html           ← базовый шаблон (navbar, Bootstrap 5.2.3)
# │   ├── index.html          ← главная (список, пагинация, поиск)
# │   ├── post.html           ← страница поста
# │   ├── create.html         ← форма создания
# │   ├── edit.html           ← форма редактирования + удаление
# │   ├── api_docs.html       ← HTML-документация API
# │   └── 404.html
# └── static/
#     └── css/
#         └── style.css
# ```

# %% [markdown]
# # 6. Тестирование REST API
#
# Тестирование проводилось через Flask test client и curl-команды. Ниже задокументирован каждый эндпоинт из задания с реальными запросами и ответами.
#
# ---
#
# ## 6.1 GET /api/posts — список всех постов
#
# ### Описание
# Возвращает список постов в формате JSON. Поддерживает пагинацию, сортировку и полнотекстовый поиск.
#
# ### Параметры запроса
#
# | Параметр | Тип | По умолчанию | Описание |
# |---|---|---|---|
# | `page` | int | 1 | Номер страницы |
# | `per_page` | int | 5 | Постов на страницу (макс. 50) |
# | `sort` | str | desc | Сортировка: `asc` или `desc` |
# | `q` | str | — | Поиск по заголовку и содержанию |
#
# ### Тест 1 — базовый запрос с пагинацией
#
# **Запрос:**
# ```bash
# curl -H "X-API-Key: demo-api-key-12345" \
#   "http://127.0.0.1:5000/api/posts?page=1&per_page=3"
# ```
#
# **Ответ (200 OK):**
# ```json
# {
#   "pagination": {
#     "has_next": true,
#     "has_prev": false,
#     "page": 1,
#     "per_page": 3,
#     "total": 7,
#     "total_pages": 3
#   },
#   "posts": [
#     {
#       "content": "Это первый пост нашего блога...",
#       "created": "2026-05-08 04:43:55",
#       "id": 1,
#       "title": "Добро пожаловать в блог!"
#     },
#     {
#       "content": "REST (Representational State Transfer) — это архитектурный стиль...",
#       "created": "2026-05-08 04:43:55",
#       "id": 2,
#       "title": "REST API: что это такое?"
#     },
#     {
#       "content": "Пагинация позволяет разбивать большой список постов на страницы...",
#       "created": "2026-05-08 04:43:55",
#       "id": 3,
#       "title": "Пагинация в Flask"
#     }
#   ]
# }
# ```
#
# ### Тест 2 — поиск с сортировкой по возрастанию
#
# **Запрос:**
# ```bash
# curl -H "X-API-Key: demo-api-key-12345" \
#   "http://127.0.0.1:5000/api/posts?q=Flask&sort=asc"
# ```
#
# **Ответ (200 OK):**
# ```json
# {
#   "pagination": {
#     "has_next": false,
#     "has_prev": false,
#     "page": 1,
#     "per_page": 5,
#     "total": 2,
#     "total_pages": 1
#   },
#   "posts": [
#     {
#       "id": 3,
#       "title": "Пагинация в Flask",
#       "content": "Пагинация позволяет разбивать большой список постов на страницы...",
#       "created": "2026-05-08 04:43:55"
#     },
#     {
#       "id": 6,
#       "title": "Flask — микрофреймворк для Python",
#       "content": "Flask — это лёгкий веб-фреймворк для Python...",
#       "created": "2026-05-08 04:43:55"
#     }
#   ]
# }
# ```
#
# ### Тест 3 — запрос без API-ключа
#
# **Запрос:**
# ```bash
# curl http://127.0.0.1:5000/api/posts
# ```
#
# **Ответ (401 Unauthorized):**
# ```json
# {
#   "error": "Unauthorized. Provide a valid API key."
# }
# ```
#
# ---
#
# ## 6.2 GET /api/posts/\<id\> — конкретный пост
#
# ### Описание
# Возвращает один пост по числовому `id`. Если пост не существует — 404.
#
# ### Тест 1 — существующий пост
#
# **Запрос:**
# ```bash
# curl -H "X-API-Key: demo-api-key-12345" http://127.0.0.1:5000/api/posts/1
# ```
#
# **Ответ (200 OK):**
# ```json
# {
#   "content": "Это первый пост нашего блога. Здесь вы найдёте интересные статьи на разные темы. Используйте REST API для программного доступа к постам.",
#   "created": "2026-05-08 04:43:55",
#   "id": 1,
#   "title": "Добро пожаловать в блог!"
# }
# ```
#
# ### Тест 2 — несуществующий пост
#
# **Запрос:**
# ```bash
# curl -H "X-API-Key: demo-api-key-12345" http://127.0.0.1:5000/api/posts/9999
# ```
#
# **Ответ (404 Not Found):**
# ```json
# {
#   "error": "Post 9999 not found."
# }
# ```
#
# ---
#
# ## 6.3 POST /api/posts — создание нового поста
#
# ### Описание
# Принимает JSON-тело с обязательными полями `title` и `content`. Возвращает созданный пост с кодом **201 Created**.
#
# ### Тест 1 — успешное создание
#
# **Запрос:**
# ```bash
# curl -X POST \
#   -H "X-API-Key: demo-api-key-12345" \
#   -H "Content-Type: application/json" \
#   -d '{"title": "Тестовый пост", "content": "Создан через REST API"}' \
#   http://127.0.0.1:5000/api/posts
# ```
#
# **Ответ (201 Created):**
# ```json
# {
#   "content": "Создан через REST API",
#   "created": "2026-05-08 04:43:56",
#   "id": 8,
#   "title": "Тестовый пост"
# }
# ```
#
# ### Тест 2 — ошибка: пустой заголовок (422)
#
# **Запрос:**
# ```bash
# curl -X POST \
#   -H "X-API-Key: demo-api-key-12345" \
#   -H "Content-Type: application/json" \
#   -d '{"title": "", "content": "Текст"}' \
#   http://127.0.0.1:5000/api/posts
# ```
#
# **Ответ (422 Unprocessable Entity):**
# ```json
# {
#   "error": "Field \"title\" is required."
# }
# ```
#
# ### Тест 3 — ошибка: пустое содержание (422)
#
# **Запрос:**
# ```bash
# curl -X POST \
#   -H "X-API-Key: demo-api-key-12345" \
#   -H "Content-Type: application/json" \
#   -d '{"title": "Заголовок", "content": ""}' \
#   http://127.0.0.1:5000/api/posts
# ```
#
# **Ответ (422 Unprocessable Entity):**
# ```json
# {
#   "error": "Field \"content\" is required."
# }
# ```
#
# ### Тест 4 — ошибка: тело не JSON (400)
#
# **Запрос:**
# ```bash
# curl -X POST \
#   -H "X-API-Key: demo-api-key-12345" \
#   -d 'not json' \
#   http://127.0.0.1:5000/api/posts
# ```
#
# **Ответ (400 Bad Request):**
# ```json
# {
#   "error": "Invalid or missing JSON body."
# }
# ```
#
# ---
#
# ## 6.4 PUT /api/posts/\<id\> — обновление поста
#
# ### Описание
# Обновляет существующий пост. Можно передать одно или оба поля — непереданные сохраняются без изменений (частичное обновление).
#
# ### Тест 1 — обновление обоих полей
#
# **Запрос:**
# ```bash
# curl -X PUT \
#   -H "X-API-Key: demo-api-key-12345" \
#   -H "Content-Type: application/json" \
#   -d '{"title": "Обновлённый заголовок", "content": "Обновлённое содержание"}' \
#   http://127.0.0.1:5000/api/posts/8
# ```
#
# **Ответ (200 OK):**
# ```json
# {
#   "content": "Обновлённое содержание",
#   "created": "2026-05-08 04:43:56",
#   "id": 8,
#   "title": "Обновлённый заголовок"
# }
# ```
#
# ### Тест 2 — частичное обновление (только title)
#
# **Запрос:**
# ```bash
# curl -X PUT \
#   -H "X-API-Key: demo-api-key-12345" \
#   -H "Content-Type: application/json" \
#   -d '{"title": "Только заголовок изменён"}' \
#   http://127.0.0.1:5000/api/posts/1
# ```
#
# **Ответ (200 OK):** поле `content` остаётся прежним, изменён только `title`.
#
# ### Тест 3 — ошибка: пост не найден (404)
#
# **Запрос:**
# ```bash
# curl -X PUT \
#   -H "X-API-Key: demo-api-key-12345" \
#   -H "Content-Type: application/json" \
#   -d '{"title": "Тест"}' \
#   http://127.0.0.1:5000/api/posts/9999
# ```
#
# **Ответ (404 Not Found):**
# ```json
# {
#   "error": "Post 9999 not found."
# }
# ```
#
# ---
#
# ## 6.5 DELETE /api/posts/\<id\> — удаление поста
#
# ### Описание
# Безвозвратно удаляет пост. Возвращает сообщение об успехе или 404 если пост не найден.
#
# ### Тест 1 — успешное удаление
#
# **Запрос:**
# ```bash
# curl -X DELETE \
#   -H "X-API-Key: demo-api-key-12345" \
#   http://127.0.0.1:5000/api/posts/8
# ```
#
# **Ответ (200 OK):**
# ```json
# {
#   "message": "Post 8 deleted successfully."
# }
# ```
#
# ### Тест 2 — ошибка: пост не найден (404)
#
# **Запрос:**
# ```bash
# curl -X DELETE \
#   -H "X-API-Key: demo-api-key-12345" \
#   http://127.0.0.1:5000/api/posts/9999
# ```
#
# **Ответ (404 Not Found):**
# ```json
# {
#   "error": "Post 9999 not found."
# }
# ```
#
# ---
#
# ## 6.6 GET /api/docs — документация API
#
# ### Описание
# Публичная HTML-страница с документацией. Аутентификация **не требуется**. Содержит: таблицу всех эндпоинтов, описание параметров, примеры curl-команд, таблицу HTTP-кодов ошибок.
#
# **Запрос:**
# ```bash
# curl http://127.0.0.1:5000/api/docs
# # или открыть в браузере: http://127.0.0.1:5000/api/docs
# ```
#
# **Ответ (200 OK):** HTML-страница с полной документацией.
#
# ---
#
# ## 6.7 Сводная таблица HTTP-кодов
#
# | Код | Название | Когда возвращается |
# |---|---|---|
# | 200 | OK | Успешный GET, PUT, DELETE |
# | 201 | Created | Успешный POST (пост создан) |
# | 400 | Bad Request | Тело запроса не является JSON |
# | 401 | Unauthorized | Неверный или отсутствующий API-ключ |
# | 404 | Not Found | Пост с указанным ID не найден |
# | 405 | Method Not Allowed | Неподдерживаемый HTTP-метод |
# | 422 | Unprocessable Entity | Пустое обязательное поле |
# | 500 | Internal Server Error | Непредвиденная ошибка сервера |
#
# ## 6.8 Результаты тестирования веб-интерфейса
#
# | Функция | Результат |
# |---|---|
# | Главная страница — список постов | ✅ Работает |
# | Пагинация (5 постов на страницу) | ✅ Работает |
# | Поиск по заголовку и содержанию | ✅ Работает |
# | Просмотр поста | ✅ Работает |
# | Создание поста (форма) | ✅ Работает |
# | Редактирование поста (форма) | ✅ Работает |
# | Удаление с подтверждением | ✅ Работает |
# | Flash-сообщения об ошибках | ✅ Работает |
# | Экспорт в CSV | ✅ Работает |
# | Документация API `/api/docs` | ✅ Работает |
# | Страница 404 | ✅ Работает |

# %% [markdown]
# # 7. Проблемы и их решение
#
# ## Проблема 1: API возвращал HTML вместо JSON при ошибках 404/500
#
# **Описание:** При обращении к несуществующему API-маршруту Flask по умолчанию возвращал HTML-страницу ошибки, что некорректно для REST API.
#
# **Решение:** Добавлены кастомные `@app.errorhandler`, которые проверяют путь запроса и возвращают JSON для `/api/` маршрутов:
# ```python
# @app.errorhandler(404)
# def not_found(e):
#     if request.path.startswith('/api/'):
#         return jsonify({'error': 'Not found.'}), 404
#     return render_template('404.html'), 404
# ```
#
# ---
#
# ## Проблема 2: SQL-инъекция при динамической сортировке
#
# **Описание:** Параметр `sort` подставлялся в SQL напрямую. Параметризованные запросы не поддерживают ключевые слова ORDER BY, поэтому `?` здесь неприменим.
#
# **Решение:** Белый список допустимых значений:
# ```python
# sort = request.args.get('sort', 'desc').lower()
# if sort not in ('asc', 'desc'):
#     sort = 'desc'  # сброс к безопасному значению
# order = f'created {sort.upper()}'
# ```
#
# ---
#
# ## Проблема 3: Пагинация сбрасывала поисковый запрос
#
# **Описание:** При переходе на следующую страницу параметр `?q=` терялся из URL.
#
# **Решение:** Параметр `q` явно передаётся в `url_for()` во всех ссылках пагинации:
# ```html
# <a class="page-link" href="{{ url_for('index', page=p, q=q) }}">{{ p }}</a>
# ```

# %% [markdown]
# # 8. Выводы
#
# ## 8.1 Чему научился
#
# - **REST API на Flask** — маршруты с GET/POST/PUT/DELETE, использование `jsonify`, правильные HTTP-коды
# - **Аутентификация через API-ключ** — реализация декоратора с `functools.wraps`
# - **Пагинация на уровне SQL** — `LIMIT` и `OFFSET` для постраничной выборки без загрузки всей таблицы
# - **Полнотекстовый поиск** — `LIKE '%текст%'` по нескольким полям через `OR`
# - **Экспорт в CSV** — формирование файла в памяти через `io.StringIO` и отдача через `flask.Response`
# - **Обработка ошибок** — `@app.errorhandler` с разными форматами ответа для API и веб
# - **Безопасность** — параметризованные SQL-запросы, белый список для динамических частей
# - **Шаблонизация Jinja2** — наследование шаблонов (`extends`/`block`), передача переменных
#
# ## 8.2 Что можно улучшить
#
# | Улучшение | Описание |
# |---|---|
# | Аутентификация пользователей | Flask-Login для защиты маршрутов редактирования/удаления |
# | Хранение API-ключей в БД | Таблица `api_keys` с привязкой к пользователю и возможностью отзыва |
# | Rate limiting | Ограничение числа запросов к API (Flask-Limiter) |
# | Swagger/OpenAPI | Автогенерация документации через flask-openapi3 |
# | Автотесты | pytest + flask.testing.FlaskClient |
# | Развёртывание | Gunicorn + Nginx вместо встроенного Flask-сервера |
#
# ## 8.3 Оценка сложности
#
# | Компонент | Сложность | Комментарий |
# |---|---|---|
# | Базовый CRUD веб-интерфейс | ⭐⭐ | Хорошо описан в лекции |
# | REST API — 5 эндпоинтов + /api/docs | ⭐⭐⭐ | Требует понимания HTTP и форматов ответов |
# | Декоратор аутентификации | ⭐⭐⭐ | Нужны знания `functools.wraps` |
# | Пагинация + поиск SQL | ⭐⭐⭐ | `LIMIT/OFFSET` и `LIKE` в двух режимах |
# | Экспорт в CSV | ⭐⭐ | Стандартная библиотека Python |
# | Обработчики ошибок API/web | ⭐⭐ | Понятная логика разветвления |
#
# **Общая оценка сложности: 3/5** — задание выполнимо за одно занятие при наличии базовых знаний Flask и SQL. Наибольшую сложность представляет грамотная обработка ошибок и обеспечение безопасности API.
